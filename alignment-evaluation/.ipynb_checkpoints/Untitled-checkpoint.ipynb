# %%
# !ls ../evaluation-data/
# Out:
# Dialign		    spam-align-w-4_d-7	 spam-align-w-7_d-11
# fast-bb-aligned     spam-align-w-4_d-8	 spam-align-w-7_d-12
# Mafft		    spam-align-w-5_d-10  spam-align-w-7_d-13
# spam-align-w-3_d-3  spam-align-w-5_d-11  spam-align-w-7_d-3
# spam-align-w-3_d-4  spam-align-w-5_d-3	 spam-align-w-7_d-4
# spam-align-w-3_d-5  spam-align-w-5_d-4	 spam-align-w-7_d-5
# spam-align-w-3_d-6  spam-align-w-5_d-5	 spam-align-w-7_d-6
# spam-align-w-3_d-7  spam-align-w-5_d-6	 spam-align-w-7_d-7
# spam-align-w-4_d-3  spam-align-w-5_d-7	 spam-align-w-7_d-8
# spam-align-w-4_d-4  spam-align-w-5_d-8	 spam-align-w-7_d-9
# spam-align-w-4_d-5  spam-align-w-5_d-9
# spam-align-w-4_d-6  spam-align-w-7_d-10

# %%
import json, os, pandas as pd

# %%
results_sop = []
results_cs = []
results_time = []
for program in os.listdir("../evaluation-data/"):
    if program == "fast-bb-aligned":
        continue
    results_for_prog_sop = []
    results_for_prog_cs = []
    results_for_prog_time = []

    for ref in os.listdir(f"../evaluation-data/{program}"):
        with open(f'../evaluation-data/{program}/{ref}/aggr.json') as f:
            data = json.load(f)
            results_for_prog_sop.append(data['sum_of_pairs'])
            results_for_prog_cs.append(data['column_score'])
            results_for_prog_time.append(data['time_ms'])
    results_sop.append((program, results_for_prog_sop))
    results_cs.append((program, results_for_prog_cs))
    results_time.append((program, results_for_prog_time))

# %%
df_sop = pd.DataFrame.from_items(results_sop, columns=['RV11', 'RV50', 'RV12', 'RV20', 'RV30'], orient='index')
df_cs = pd.DataFrame.from_items(results_cs, columns=['RV11', 'RV50', 'RV12', 'RV20', 'RV30'], orient='index')
df_time = pd.DataFrame.from_items(results_time, columns=['RV11', 'RV50', 'RV12', 'RV20', 'RV30'], orient='index')

# %%
df_sop = df_sop[sorted(df_sop.columns.tolist())].sort_index()
df_cs = df_cs[sorted(df_cs.columns.tolist())].sort_index()
df_time = df_time[sorted(df_time.columns.tolist())].sort_index()

# %% [markdown]
# ## Sum of pairs score

# %%
df_sop
# Out:
#                          RV11      RV12      RV20      RV30      RV50
# Dialign              0.494482  0.851870  0.868279  0.739987  0.804629
# Mafft                0.649009  0.937053  0.926899  0.861649  0.899101
# spam-align-w-3_d-3   0.142159  0.606218  0.702234  0.484244  0.538483
# spam-align-w-3_d-4   0.155794  0.658905  0.766577  0.553660  0.578644
# spam-align-w-3_d-5   0.188812  0.677427  0.808474  0.604711  0.644325
# spam-align-w-3_d-6   0.213020  0.714218  0.805814  0.646029  0.657372
# spam-align-w-3_d-7   0.191470  0.740705  0.842134  0.674685  0.695700
# spam-align-w-4_d-3   0.113892  0.583015  0.751375  0.553807  0.559935
# spam-align-w-4_d-4   0.148506  0.604604  0.785049  0.588540  0.612395
# spam-align-w-4_d-5   0.160535  0.641308  0.791867  0.630944  0.631435
# spam-align-w-4_d-6   0.135518  0.649984  0.805050  0.638779  0.650144
# spam-align-w-5_d-5   0.002249  0.291706  0.077480  0.151918  0.201940
# spam-align-w-5_d-6   0.002470  0.272492  0.054622  0.142312  0.215119
# spam-align-w-5_d-7   0.002078  0.254765  0.063277  0.154603  0.196740
# spam-align-w-5_d-8   0.004409  0.274029  0.080977  0.174383  0.167887
# spam-align-w-5_d-9   0.002318  0.251814  0.063507  0.149079  0.167331
# spam-align-w-7_d-10  0.000266  0.071610  0.011176  0.017800  0.066894
# spam-align-w-7_d-11  0.000266  0.077706  0.019372  0.038377  0.065964
# spam-align-w-7_d-12  0.000266  0.078573  0.011051  0.021041  0.038899
# spam-align-w-7_d-13  0.000266  0.077818  0.002398  0.033450  0.042521
# spam-align-w-7_d-3   0.000000  0.085255  0.011055  0.046612  0.043032
# spam-align-w-7_d-4   0.000266  0.091684  0.008791  0.041187  0.066145
# spam-align-w-7_d-5   0.000266  0.077383  0.011339  0.024664  0.068458
# spam-align-w-7_d-6   0.000266  0.082943  0.011461  0.037576  0.056434
# spam-align-w-7_d-7   0.000266  0.085637  0.009551  0.027185  0.052733
# spam-align-w-7_d-8   0.000266  0.081705  0.010913  0.028054  0.047782
# spam-align-w-7_d-9   0.000266  0.083230  0.008991  0.023225  0.057983

# %% [markdown]
# ## Execution time in ms

# %%
df_time
# Out:
#                      RV11  RV12   RV20   RV30   RV50
# Dialign               543  1626  40116  85923  23141
# Mafft                 986  1189  15228  19334  24774
# spam-align-w-3_d-3     26    73   1907   3713   1060
# spam-align-w-3_d-4     29    81   1973   3904   1080
# spam-align-w-3_d-5     29    75   1982   4025   1048
# spam-align-w-3_d-6     32    82   2005   4013    998
# spam-align-w-3_d-7     34    78   2010   4179    995
# spam-align-w-4_d-3     16    51   1444   3096    774
# spam-align-w-4_d-4     15    55   1479   3104    756
# spam-align-w-4_d-5     18    55   1523   3168    699
# spam-align-w-4_d-6     18    54   1582   3173    732
# spam-align-w-4_d-7     18    58   1514   3234    753
# spam-align-w-4_d-8     20    61   1558   3146    766
# spam-align-w-5_d-10    12    48   1400   2909    661
# spam-align-w-5_d-11    11    45   1401   2951    601
# spam-align-w-5_d-3     10    37   1284   2757    607
# spam-align-w-5_d-4     11    38   1261   2823    556
# spam-align-w-5_d-5     12    42   1323   2782    586
# spam-align-w-5_d-6     12    41   1343   2861    627
# spam-align-w-5_d-7     11    40   1355   2825    634
# spam-align-w-5_d-8     13    42   1401   2902    615
# spam-align-w-5_d-9     14    44   1393   2959    660
# spam-align-w-7_d-10     9    30   1179   2205    412
# spam-align-w-7_d-11     9    26   1184   2255    411
# spam-align-w-7_d-12    10    26   1155   2321    427
# spam-align-w-7_d-13     9    26   1111   2242    424
# spam-align-w-7_d-3     11    23   1084   2134    371
# spam-align-w-7_d-4     10    25   1025   2112    394
# spam-align-w-7_d-5     10    24   1031   2172    397
# spam-align-w-7_d-6     10    26   1070   2193    428
# spam-align-w-7_d-7     11    25   1051   2177    395
# spam-align-w-7_d-8      9    28   1089   2289    380
# spam-align-w-7_d-9      9    27   1163   2272    416
